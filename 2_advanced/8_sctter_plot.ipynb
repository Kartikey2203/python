# %%
import ast
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt

dataset = load_dataset("lukebarousse/data_jobs")
df = dataset["train"].to_pandas()

df["job_posted_date"] = pd.to_datetime(df["job_posted_date"])
df["job_skills"] = df["job_skills"].apply(
    lambda x: ast.literal_eval(x) if pd.notna(x) else x
)

# %%
df=df[df['job_title_short']=='Data Analyst']

# %%
df
# Out:
#        job_title_short                                          job_title  \
# 1         Data Analyst                                       Data Analyst
# 12        Data Analyst        Stagiaire Data Analyst (H/F) - Lyon (69006)
# 18        Data Analyst                                       Data Analyst
# 31        Data Analyst                           Stage - Data Analyst F/H
# 34        Data Analyst  Data Analyst als Marketing Manager Automation ...
# ...                ...                                                ...
# 785703    Data Analyst            Data Analyst - CRYPTOGRAPHY - Full-time
# 785705    Data Analyst          Expert Business Data Analyst - Now Hiring
# 785715    Data Analyst  Amul Careers 2023 - Apply Online - Data Analys...
# 785717    Data Analyst                 Data & Analytics Architect (w/m/x)
# 785737    Data Analyst                                   CRM Data Analyst
#
#                         job_location  \
# 1       Guadalajara, Jalisco, Mexico
# ...

# %%
df_exploded=df.explode('job_skills')
skill_stat=df_exploded.groupby('job_skills').agg(
    skill_count=('job_skills','count'),
    med_sal=('salary_year_avg','median')
)
skills_stat=skill_stat.sort_values(by='skill_count',ascending=False).head(20)
skills_stat.plot(kind='scatter',x='skill_count',y='med_sal')
plt.xlabel('Count of Job Postings')
plt.ylabel('Median Yearly Salary ($USD)')
plt.title('Salary vs. Count of Job Postings for Top 10 Skills')

plt.tight_layout()
plt.show()

# %%
df_DA = df[df['job_title_short'] == 'Data Analyst'].copy()

# create a new column for month number
df_DA['job_posted_month_no'] = df_DA['job_posted_date'].dt.month

# Explode the job_skills column and pivot
df_DA_explode = df_DA.explode('job_skills')
df_DA_pivot = df_DA_explode.pivot_table(
    index='job_posted_month_no',
    columns='job_skills',
    aggfunc='size',
    fill_value=0
)

# sort the skills by count
df_DA_pivot.loc['Total'] = df_DA_pivot.sum()
df_DA_pivot = df_DA_pivot[df_DA_pivot.loc['Total'].sort_values(ascending=False).index]
df_DA_pivot = df_DA_pivot.drop('Total')

# Use month names for plotting
df_DA_pivot = df_DA_pivot.reset_index()
df_DA_pivot['job_posted_month'] = df_DA_pivot['job_posted_month_no'].apply(
    lambda x: pd.to_datetime(str(x), format='%m').strftime('%B')
)
df_DA_pivot = df_DA_pivot.set_index('job_posted_month')
df_DA_pivot = df_DA_pivot.drop(columns='job_posted_month_no')

# Get the top 5 skills
df_DA_pivot.iloc[:, :5].plot(kind='line')

plt.title('Top 5 Skills for Data Analysts per Month')
plt.ylabel('Count')
plt.xlabel('Month')
plt.show()

# %%
df_DA_pivot.iloc[:, :5].plot(
    kind='line',
    linewidth=4,
    linestyle='--',
    colormap='plasma',
    markersize=5,
    marker='*',
    figsize=(10, 5)
)

plt.show()

# %%
conda install -c conda-forge adjustText
# Out:
# 3 channel Terms of Service accepted
# Channels:
#  - conda-forge
#  - defaults
# Platform: win-64
# ...
# Solving environment: done
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
from adjustText import adjust_text

# %%
texts=[]
skills_stat.plot(kind='scatter',x='skill_count',y='med_sal')
for i,txt in enumerate(skills_stat.index):
    texts.append(plt.text(skills_stat['skill_count'].iloc[i],skills_stat['med_sal'].iloc[i],txt))
adjust_text(
    texts,
    arrowprops=dict(arrowstyle="->", color="gray", lw=1)
)
ax = plt.gca()
ax.yaxis.set_major_formatter(plt.FuncFormatter(lambda y, pos: f'${int(y/1000)}K'))


plt.xlabel('Count of Job Postings')
plt.ylabel('Median Yearly Salary ($USD)')
skill_count = 20
plt.title(f'Salary vs. Count of Job Postings for Top {skill_count} Skills')

plt.tight_layout()
plt.show()

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[16], line 3
#       1 for i,txt in enumerate(skill_stat.index):
#       2     plt.text(skill_stat['skill_count'].iloc[i],skill_stat['med_sal'].iloc[i],txt)
# ----> 3 adjust_text(txt)
#
# File c:\Users\karti\anaconda3\envs\python_course\Lib\site-packages\adjustText\__init__.py:599, in adjust_text(texts, x, y, objects, target_x, target_y, avoid_self, prevent_crossings, force_text, force_static, force_pull, force_explode, pull_threshold, expand, max_move, explode_radius, ensure_inside_axes, expand_axes, only_move, ax, min_arrow_len, time_lim, iter_lim, *args, **kwargs)
#     596 force_draw(ax)
#     598 try:
# --> 599     transform = texts[0].get_transform()
#     600 except IndexError:
#     601     logger.warn(
#     602         "Something wrong with the texts. Did you pass a list of matplotlib text objects?"
# ...
