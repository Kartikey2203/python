# %%
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt

# Loading Data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# Data Cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %%
df.pivot_table(values='salary_year_avg', index='job_title_short',aggfunc='median')
# Out:
#                            salary_year_avg
# job_title_short
# Business Analyst                   85000.0
# Cloud Engineer                     90000.0
# Data Analyst                       90000.0
# Data Engineer                     125000.0
# Data Scientist                    127500.0
# Machine Learning Engineer         106415.0
# Senior Data Analyst               111175.0
# Senior Data Engineer              147500.0
# Senior Data Scientist             155500.0
# Software Engineer                  99150.0

# %%
df_job_country=df.pivot_table(values='salary_year_avg', index='job_country' ,columns='job_title_short',aggfunc='median')

# %%
top_country=df['job_country'].value_counts().head(5).index
df_job_country=df_job_country.loc[top_country]
job_titles = ['Data Analyst', 'Data Engineer', 'Data Scientist']
df_job_country=df_job_country[job_titles]
df_job_country
# Out:
# job_title_short  Data Analyst  Data Engineer  Data Scientist
# job_country
# United States         90000.0       125000.0        130000.0
# India                100500.0       147500.0        114008.0
# United Kingdom        87750.0       110000.0        105300.0
# France                69175.0        98301.5         88128.0
# Germany              103750.0       147500.0        131560.0

# %%
df_job_country.plot(kind='bar')
plt.ylabel('Median Salary ($USD)')
plt.xlabel('')
plt.title('Median Salary by Country and Job Title')
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
df_usa = df[df.job_country == 'United States'].copy()
# extract month name from the posting date for grouping
df_usa['job_posted_month'] = df_usa['job_posted_date'].dt.strftime('%B')
df_usa.reset_index(inplace=True)
df_usa
# Out:
#          index       job_title_short  \
# 0            0  Senior Data Engineer
# 1            3         Data Engineer
# 2            5         Data Engineer
# 3            6  Senior Data Engineer
# 4            9        Data Scientist
# ...        ...                   ...
# 206287  785673        Data Scientist
# 206288  785685          Data Analyst
# 206289  785692        Data Scientist
# 206290  785703          Data Analyst
# 206291  785705          Data Analyst
#
#                                                 job_title      job_location  \
# 0       Senior Clinical Data Engineer / Principal Clin...     Watertown, CT
# 1       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...   San Antonio, TX
# 2                                       GCP Data Engineer          Anywhere
# 3                       Senior Data Engineer  - GCP Cloud      Dearborn, MI
# 4                                       Data Scientist II          Anywhere
# ...

# %%
# 1. Check columns
print(df_usa.columns)

# 2. Create month if needed
df_usa['job_posted_month'] = pd.to_datetime(
    df_usa['job_posted_date']
).dt.month_name()

# 3. Pivot
df_US_pivot = df_usa.pivot_table(
    index='job_posted_month',
    columns='job_title_short',
    aggfunc='size'
)
# Out:
# Index(['index', 'job_title_short', 'job_title', 'job_location', 'job_via',
#        'job_schedule_type', 'job_work_from_home', 'search_location',
#        'job_posted_date', 'job_no_degree_mention', 'job_health_insurance',
#        'job_country', 'salary_rate', 'salary_year_avg', 'salary_hour_avg',
#        'company_name', 'job_skills', 'job_type_skills', 'job_posted_month'],
#       dtype='object')

# %%
df_US_pivot.reset_index(inplace=True)

df_US_pivot['month_no'] = pd.to_datetime(
    df_US_pivot['job_posted_month'],
    format='%B'
).dt.month

df_US_pivot.sort_values('month_no', inplace=True)

df_US_pivot = df_US_pivot.set_index('job_posted_month')
df_US_pivot
# Out:
# job_title_short   Business Analyst  Cloud Engineer  Data Analyst  \
# job_posted_month
# January                        527              36          8494
# February                       447              24          6124
# March                          438              19          6218
# April                          565              40          6049
# May                            279              20          4993
# June                           446              32          5683
# July                           581              39          5201
# August                         903              39          6634
# September                      897              50          4639
# October                        932              48          5271
# November                       719              36          4531
# December                       648              40          3979
#
# job_title_short   Data Engineer  Data Scientist  Machine Learning Engineer  \
# job_posted_month
# ...

# %%
df_US_pivot.plot(kind='line')
# Out:
# <Axes: xlabel='job_posted_month'>

# %%
top_3=df_usa['job_title_short'].value_counts().head(3)
top_3=top_3.index.to_list()
top_3
# Out:
# ['Data Analyst', 'Data Scientist', 'Data Engineer']

# %%
df_US_pivot[top_3].plot(kind="line")
# Out:
# <Axes: xlabel='job_posted_month'>

# %%
df_usa_soft_pivot = pd.read_csv("https://lukeb.co/software_csv",index_col='job_posted_month')
df_usa_soft_pivot
# Out:
#                   Front-End Developer  Back-End Developer  \
# job_posted_month
# January                         13619                9827
# February                        11456                9116
# March                           11102                8178
# April                           14037                9209
# May                             12126                8864
# June                            12003                8065
# July                            11914                8061
# August                          11571                8191
# September                       14016                8447
# October                         11419                8476
# November                        13771                9034
# December                        14033                9232
#
#                   Full-Stack Developer  UI/UX Designer
# job_posted_month
# January                           5108            4348
# February                          7298            4284
# ...

# %%
df_us_merge=df_US_pivot.merge(df_usa_soft_pivot,on='job_posted_month')

# %%
top_5=df_us_merge.sum().sort_values(ascending=False).head().index.to_list()
top_5
# Out:
# ['Front-End Developer',
#  'Back-End Developer',
#  'Full-Stack Developer',
#  'Data Analyst',
#  'Data Scientist']

# %%
df_us_merge[top_5].plot(kind='line', figsize=(10, 6))

plt.title('Monthly Job Postings for Top Tech Jobs in the US')
plt.xlabel('Month')
plt.ylabel('Job Count')
plt.ylim(0, 20000)

plt.legend(title='Job Title')
plt.show()
